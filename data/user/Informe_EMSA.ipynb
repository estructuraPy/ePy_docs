# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from ePy_units.converter import UnitConverter
converter = UnitConverter("structural")

from ePy_docs.writers import DocumentWriter
writer = DocumentWriter("report", "handwritten", language="es")

# %%
writer.get_available_document_types()
# Out:
# {'paper': 'Documento científico/académico con columnas múltiples',
#  'report': 'Reporte técnico/profesional, típicamente una columna',
#  'book': 'Libro o manual extenso, formato libro',
#  'presentation': 'Presentaciones formato paisaje',
#  'notebook': 'Cuaderno de cálculo interactivo'}

# %%
writer.get_available_layouts()
# Out:
# {'academic': 'Layout académico - Referencias a configuración compartida',
#  'classic': 'Layout clásico - Referencias a configuración compartida',
#  'corporate': 'Layout corporativo - Referencias a configuración compartida',
#  'creative': 'Layout creativo - Referencias a configuración compartida',
#  'handwritten': 'Layout manuscrito - Referencias a configuración compartida',
#  'minimal': 'Layout minimalista - Referencias a configuración compartida',
#  'professional': 'Layout profesional - Referencias a configuración compartida',
#  'scientific': 'Layout científico - Referencias a configuración compartida',
#  'technical': 'Layout técnico - Referencias a configuración compartida'}

# %%
writer.get_available_palettes()
# Out:
# {'reds': 'Paleta roja intensa: rosa claro a rojo profundo y magenta',
#  'blues': 'Paleta azul cielo suave: gradiente azul claro a navy profundo',
#  'greens': 'Paleta verde esmeralda: tonos verdes frescos y teal',
#  'purples': 'Paleta púrpura vibrante: lavanda a violeta profundo',
#  'oranges': 'Paleta naranja cálida: amarillo-naranja brillante a naranja oscuro',
#  'yellows': 'Paleta amarilla cálida: amarillo brillante a dorado',
#  'grays': 'Paleta gris neutra: tonos grises equilibrados',
#  'handwritten': 'Paleta tierra natural: tonos grises/dorados cálidos',
#  'minimal': 'Paleta monocromática pura: solo blanco y negro para minimal',
#  'monochrome': 'Paleta gris pizarra minimalista: tonos slate sutiles',
#  'classic': 'Paleta beige/crema clásica: tonos tierra cálidos tradicionales',
#  'academic': 'Paleta azul académica: tonos azules serios y profesionales',
#  'professional': 'Paleta azul cielo profesional: gradiente de azules claros a navy',
#  'scientific': 'Paleta cian científica: tonos turquesa/aguamarina brillantes',
#  'info': 'Paleta azul información: azules brillantes informativos para datos y detalles',
#  'technical': 'Paleta gris técnica: tonos industriales modernos',
#  'corporate': 'Paleta azul corporativa: azules profesionales de negocio',
#  'creative': 'Paleta magenta creativa: tonos vibrantes rosa/magenta',
#  'neutrals': 'Paleta neutral balanceada: grises cálidos equilibrados'}

# %%
writer.add_quarto_file(r"chapters/Ch0_responsability.qmd")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 writer.add_quarto_file(r"chapters/Ch0_responsability.qmd")
#
# File ~\estructuraPy\ePy_docs\src\ePy_docs\writers.py:731, in DocumentWriter.add_quarto_file(self, file_path, include_yaml, fix_image_paths, convert_tables, execute_code_blocks)
#     694 def add_quarto_file(self, file_path: str, include_yaml: bool = False,
#     695                    fix_image_paths: bool = True, convert_tables: bool = True,
#     696                    execute_code_blocks: bool = True) -> 'DocumentWriter':
#     697     """Import and append content from an existing Quarto (.qmd) file.
#     698
#     699     The imported content is automatically separated from existing content with spacers
#    (...)    729         writer.add_quarto_file("results.qmd", convert_tables=True, execute_code_blocks=True)
#     730     """
# --> 731     super().add_quarto_file(file_path, include_yaml, fix_image_paths, convert_tables, execute_code_blocks)
#     732     return self
#
# File ~\estructuraPy\ePy_docs\src\ePy_docs\core\_text.py:752, in DocumentWriterCore.add_quarto_file(self, file_path, include_yaml, fix_image_paths, convert_tables, execute_code_blocks)
#     747 def add_quarto_file(self, file_path: str, include_yaml: bool = False,
#     748                    fix_image_paths: bool = True, convert_tables: bool = True,
#     749                    execute_code_blocks: bool = True):
#     750     from ePy_docs.core._quarto import process_quarto_file
# --> 752     process_quarto_file(
#     753         file_path=file_path, include_yaml=include_yaml, fix_image_paths=fix_image_paths,
#     754         convert_tables=convert_tables, output_dir=self.output_dir,
#     755         figure_counter=self._counters['figure'] + 1,
#     756         document_type=self.document_type, writer_instance=self,
#     757         execute_code_blocks=execute_code_blocks
#     758     )
#
# File ~\estructuraPy\ePy_docs\src\ePy_docs\core\_quarto.py:677, in process_quarto_file(file_path, include_yaml, fix_image_paths, convert_tables, output_dir, figure_counter, document_type, writer_instance, execute_code_blocks)
#     674 from pathlib import Path
#     676 # Read file
# --> 677 with open(file_path, 'r', encoding='utf-8') as f:
#     678     content = f.read()
#     680 # Skip YAML if requested
#
# FileNotFoundError: [Errno 2] No such file or directory: 'chapters/Ch0_responsability.qmd'

# %%
writer.add_quarto_file(r"chapters\ChA_Introduction.qmd")

# %% [markdown]
# writer.add_word_file(r"chapters\inspección_corredores_0_3_0.docx")

# %%
writer.add_quarto_file(r"chapters\ChF_References.qmd")

# %%
writer.generate(html=True, pdf=True, docx=True, output_filename="prueba 1")
